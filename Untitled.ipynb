# %%
from tensorflow.keras.utils import img_to_array,load_img
import numpy as np
import glob
import os 
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
import argparse
from PIL import Image

# %%
imagestore=[]


for v in range(1,35):
  imagestore=[]
  video_source_path='content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/'+str(v)
  print(video_source_path)
  fps=5
#fps refers to the number of seconds after which one frame will be taken . fps=5 means 1 frame after every 5 seconds. More like seconds per frame.

  def create_dir(path):
    if not os.path.exists(path):
      os.makedirs(path)

  def remove_old_images(path):
    filelist = glob.glob(os.path.join(path, "*.png"))
    for f in filelist:
      os.remove(f)

  def store(image_path):
	  img=load_img(image_path)
	  img=img_to_array(img)
	#Resize the Image to (227,227,3) for the network to be able to process it. 
	  img=resize(img,(227,227,3))
	#Convert the Image to Grayscale
	  gray=0.2989*img[:,:,0]+0.5870*img[:,:,1]+0.1140*img[:,:,2]
	  imagestore.append(gray)
#List of all Videos in the Source Directory.
  videos=os.listdir(video_source_path)
  print("Found ",len(videos)," training videos")


#Make a temp dir to store all the frames
  create_dir(video_source_path+'/frames')

#Remove old images
  remove_old_images(video_source_path+'/frames')

  framepath=video_source_path+'/frames'

  for video in videos:
		  os.system( 'ffmpeg -i {}/{} -r 1/{}  {}/frames/%03d.jpg'.format(video_source_path,video,fps,video_source_path))
		  images=os.listdir(framepath)
		  for image in images:
			  image_path=framepath+ '/'+ image
			  store(image_path)


  imagestore=np.array(imagestore)
  a,b,c=imagestore.shape
#Reshape to (227,227,batch_size)
  imagestore.resize(b,c,a)
#Normalize
  imagestore=(imagestore-imagestore.mean())/(imagestore.std())
#Clip negative Values
  imagestore=np.clip(imagestore,0,1)
  np.save('trainer.npy',imagestore)
#Remove Buffer Directory
  os.system('rm -r {}'.format(framepath))
  print("Program ended. Please wait while trainer.npy is created. \nRefresh when needed")
  print('Number of frames created :', int(len(imagestore)))
# Out:
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/1
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/2
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/3
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/4
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/5
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/6
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/7
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/8
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/9
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/10
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/11
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/12
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/13
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/14
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/15
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/16
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/17
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/18
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/19
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/20
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/21
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/22
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/23
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/24
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/25
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/26
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/27
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/28
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/29
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/30
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/31
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/32
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/33
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227
# content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train/34
# Found  1  training videos
# Program ended. Please wait while trainer.npy is created.
# Refresh when needed
# Number of frames created : 227

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np 
import argparse
from keras.layers import Conv3D,ConvLSTM2D,Conv3DTranspose
from keras.models import Sequential

# %%
def load_model():
	"""
	Return the model used for abnormal event 
	detection in videos using spatiotemporal autoencoder

	"""
	model=Sequential()
	model.add(Conv3D(filters=128,kernel_size=(11,11,1),strides=(4,4,1),padding='valid',input_shape=(227,227,10,1),activation='tanh'))
	model.add(Conv3D(filters=64,kernel_size=(5,5,1),strides=(2,2,1),padding='valid',activation='tanh'))



	model.add(ConvLSTM2D(filters=64,kernel_size=(3,3),strides=1,padding='same',dropout=0.4,recurrent_dropout=0.3,return_sequences=True))

	
	model.add(ConvLSTM2D(filters=32,kernel_size=(3,3),strides=1,padding='same',dropout=0.3,return_sequences=True))


	model.add(ConvLSTM2D(filters=64,kernel_size=(3,3),strides=1,return_sequences=True, padding='same',dropout=0.5))




	model.add(Conv3DTranspose(filters=128,kernel_size=(5,5,1),strides=(2,2,1),padding='valid',activation='tanh'))
	model.add(Conv3DTranspose(filters=1,kernel_size=(11,11,1),strides=(4,4,1),padding='valid',activation='tanh'))

	model.compile(optimizer='adam',loss='mean_squared_error',metrics=['accuracy'])

	return model

# %%
X_train=np.load('trainer.npy')
frames=X_train.shape[2]
frames=frames-frames%10
X_train=X_train[:,:,:frames]
X_train=X_train.reshape(-1,227,227,10)
X_train=np.expand_dims(X_train,axis=4)
Y_train=X_train.copy()
epochs=200
batch_size=1

# %%
if __name__=="__main__":

	model=load_model()

	callback_save = ModelCheckpoint("AnomalyDetector.h5",monitor="mean_squared_error")

	callback_early_stopping = EarlyStopping(monitor='loss', patience=3)

	print('Trainer has been loaded')
	model.fit(X_train,Y_train,
			  batch_size=batch_size,
			  epochs=epochs,
			  callbacks = [callback_save,callback_early_stopping]
			  )
print('Done\n Please wait while AnomalyDetector.h5 has been created \nRefresh when needed')
# Out:
# Trainer has been loaded
# Epoch 1/200
# 20/20 [==============================] - 28s 1s/step - loss: 0.2378 - accuracy: 0.5686
# Epoch 2/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.2046 - accuracy: 0.5880
# Epoch 3/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.1892 - accuracy: 0.6026
# Epoch 4/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.1680 - accuracy: 0.6291
# Epoch 5/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.1617 - accuracy: 0.6421
# Epoch 6/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.1538 - accuracy: 0.6577
# Epoch 7/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.1311 - accuracy: 0.7012
# Epoch 8/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.1044 - accuracy: 0.7524
# Epoch 9/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0875 - accuracy: 0.7743
# Epoch 10/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0771 - accuracy: 0.7873
# Epoch 11/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0709 - accuracy: 0.7941
# Epoch 12/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0640 - accuracy: 0.8039
# Epoch 13/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0598 - accuracy: 0.8092
# Epoch 14/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0568 - accuracy: 0.8126
# Epoch 15/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0543 - accuracy: 0.8151
# Epoch 16/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0519 - accuracy: 0.8174
# Epoch 17/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0502 - accuracy: 0.8191
# Epoch 18/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0487 - accuracy: 0.8206
# Epoch 19/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0473 - accuracy: 0.8222
# Epoch 20/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0460 - accuracy: 0.8234
# Epoch 21/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0447 - accuracy: 0.8246
# Epoch 22/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0438 - accuracy: 0.8254
# Epoch 23/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0430 - accuracy: 0.8264
# Epoch 24/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0423 - accuracy: 0.8266
# Epoch 25/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0417 - accuracy: 0.8270
# Epoch 26/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0406 - accuracy: 0.8282
# Epoch 27/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0397 - accuracy: 0.8289
# Epoch 28/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0392 - accuracy: 0.8291
# Epoch 29/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0390 - accuracy: 0.8291
# Epoch 30/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0381 - accuracy: 0.8301
# Epoch 31/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0377 - accuracy: 0.8304
# Epoch 32/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0373 - accuracy: 0.8307
# Epoch 33/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0369 - accuracy: 0.8312
# Epoch 34/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0363 - accuracy: 0.8317
# Epoch 35/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0360 - accuracy: 0.8320
# Epoch 36/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0356 - accuracy: 0.8323
# Epoch 37/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0352 - accuracy: 0.8326
# Epoch 38/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0346 - accuracy: 0.8331
# Epoch 39/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0346 - accuracy: 0.8331
# Epoch 40/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0343 - accuracy: 0.8333
# Epoch 41/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0339 - accuracy: 0.8336
# Epoch 42/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0336 - accuracy: 0.8339
# Epoch 43/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0335 - accuracy: 0.8337
# Epoch 44/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0330 - accuracy: 0.8342
# Epoch 45/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0328 - accuracy: 0.8343
# Epoch 46/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0325 - accuracy: 0.8346
# Epoch 47/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0322 - accuracy: 0.8348
# Epoch 48/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0320 - accuracy: 0.8350
# Epoch 49/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0319 - accuracy: 0.8350
# Epoch 50/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0317 - accuracy: 0.8351
# Epoch 51/200
# 20/20 [==============================] - 20s 1s/step - loss: 0.0313 - accuracy: 0.8354
# Epoch 52/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0313 - accuracy: 0.8353
# Epoch 53/200
# 20/20 [==============================] - 19s 966ms/step - loss: 0.0309 - accuracy: 0.8357
# Epoch 54/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0308 - accuracy: 0.8358
# Epoch 55/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0306 - accuracy: 0.8359
# Epoch 56/200
# 20/20 [==============================] - 19s 947ms/step - loss: 0.0305 - accuracy: 0.8360
# Epoch 57/200
# 20/20 [==============================] - 19s 945ms/step - loss: 0.0303 - accuracy: 0.8361
# Epoch 58/200
# 20/20 [==============================] - 19s 952ms/step - loss: 0.0302 - accuracy: 0.8363
# Epoch 59/200
# 20/20 [==============================] - 19s 951ms/step - loss: 0.0306 - accuracy: 0.8357
# Epoch 60/200
# 20/20 [==============================] - 19s 952ms/step - loss: 0.0300 - accuracy: 0.8363
# Epoch 61/200
# 20/20 [==============================] - 19s 951ms/step - loss: 0.0298 - accuracy: 0.8365
# Epoch 62/200
# 20/20 [==============================] - 240s 13s/step - loss: 0.0296 - accuracy: 0.8367
# Epoch 63/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0294 - accuracy: 0.8369
# Epoch 64/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0293 - accuracy: 0.8368
# Epoch 65/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0293 - accuracy: 0.8369
# Epoch 66/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0293 - accuracy: 0.8368
# Epoch 67/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0289 - accuracy: 0.8371
# Epoch 68/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0288 - accuracy: 0.8372
# Epoch 69/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0288 - accuracy: 0.8372
# Epoch 70/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0287 - accuracy: 0.8374
# Epoch 71/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0285 - accuracy: 0.8374
# Epoch 72/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0285 - accuracy: 0.8374
# Epoch 73/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0283 - accuracy: 0.8375
# Epoch 74/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0282 - accuracy: 0.8375
# Epoch 75/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0281 - accuracy: 0.8377
# Epoch 76/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0280 - accuracy: 0.8377
# Epoch 77/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0278 - accuracy: 0.8378
# Epoch 78/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0278 - accuracy: 0.8379
# Epoch 79/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0278 - accuracy: 0.8378
# Epoch 80/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0277 - accuracy: 0.8379
# Epoch 81/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0276 - accuracy: 0.8380
# Epoch 82/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0275 - accuracy: 0.8381
# Epoch 83/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0274 - accuracy: 0.8381
# Epoch 84/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0273 - accuracy: 0.8381
# Epoch 85/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0273 - accuracy: 0.8381
# Epoch 86/200
# 20/20 [==============================] - 27s 1s/step - loss: 0.0273 - accuracy: 0.8381
# Epoch 87/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0272 - accuracy: 0.8381
# Epoch 88/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0270 - accuracy: 0.8382
# Epoch 89/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0269 - accuracy: 0.8383
# Epoch 90/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0268 - accuracy: 0.8384
# Epoch 91/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0269 - accuracy: 0.8384
# Epoch 92/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0267 - accuracy: 0.8385
# Epoch 93/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0267 - accuracy: 0.8384
# Epoch 94/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0265 - accuracy: 0.8386
# Epoch 95/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0266 - accuracy: 0.8385
# Epoch 96/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0264 - accuracy: 0.8387
# Epoch 97/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0264 - accuracy: 0.8386
# Epoch 98/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0264 - accuracy: 0.8386
# Epoch 99/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0264 - accuracy: 0.8386
# Epoch 100/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0262 - accuracy: 0.8387
# Epoch 101/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0262 - accuracy: 0.8388
# Epoch 102/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0261 - accuracy: 0.8387
# Epoch 103/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0261 - accuracy: 0.8388
# Epoch 104/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0261 - accuracy: 0.8388
# Epoch 105/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0260 - accuracy: 0.8389
# Epoch 106/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0259 - accuracy: 0.8389
# Epoch 107/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0259 - accuracy: 0.8390
# Epoch 108/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0259 - accuracy: 0.8389
# Epoch 109/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0258 - accuracy: 0.8389
# Epoch 110/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0257 - accuracy: 0.8390
# Epoch 111/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0257 - accuracy: 0.8390
# Epoch 112/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0257 - accuracy: 0.8390
# Epoch 113/200
# 20/20 [==============================] - 26s 1s/step - loss: 0.0255 - accuracy: 0.8391
# Epoch 114/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0255 - accuracy: 0.8391
# Epoch 115/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0255 - accuracy: 0.8392
# Epoch 116/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0255 - accuracy: 0.8391
# Epoch 117/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0254 - accuracy: 0.8392
# Epoch 118/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0254 - accuracy: 0.8392
# Epoch 119/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0254 - accuracy: 0.8392
# Epoch 120/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0253 - accuracy: 0.8393
# Epoch 121/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0253 - accuracy: 0.8392
# Epoch 122/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0251 - accuracy: 0.8393
# Epoch 123/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0251 - accuracy: 0.8393
# Epoch 124/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0251 - accuracy: 0.8394
# Epoch 125/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0251 - accuracy: 0.8394
# Epoch 126/200
# 20/20 [==============================] - 20s 1s/step - loss: 0.0250 - accuracy: 0.8394
# Epoch 127/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0249 - accuracy: 0.8395
# Epoch 128/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0248 - accuracy: 0.8395
# Epoch 129/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0249 - accuracy: 0.8395
# Epoch 130/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0249 - accuracy: 0.8394
# Epoch 131/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0248 - accuracy: 0.8396
# Epoch 132/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0248 - accuracy: 0.8395
# Epoch 133/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0248 - accuracy: 0.8395
# Epoch 134/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0247 - accuracy: 0.8395
# Epoch 135/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0248 - accuracy: 0.8395
# Epoch 136/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0246 - accuracy: 0.8397
# Epoch 137/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0245 - accuracy: 0.8397
# Epoch 138/200
# 20/20 [==============================] - 19s 971ms/step - loss: 0.0245 - accuracy: 0.8397
# Epoch 139/200
# 20/20 [==============================] - 19s 956ms/step - loss: 0.0245 - accuracy: 0.8398
# Epoch 140/200
# 20/20 [==============================] - 19s 956ms/step - loss: 0.0246 - accuracy: 0.8395
# Epoch 141/200
# 20/20 [==============================] - 19s 966ms/step - loss: 0.0244 - accuracy: 0.8397
# Epoch 142/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0243 - accuracy: 0.8398
# Epoch 143/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0242 - accuracy: 0.8398
# Epoch 144/200
# 20/20 [==============================] - 963s 51s/step - loss: 0.0242 - accuracy: 0.8399
# Epoch 145/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0243 - accuracy: 0.8399
# Epoch 146/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0242 - accuracy: 0.8398
# Epoch 147/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0242 - accuracy: 0.8398
# Epoch 148/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0241 - accuracy: 0.8400
# Epoch 149/200
# 20/20 [==============================] - 21s 1s/step - loss: 0.0241 - accuracy: 0.8399
# Epoch 150/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0240 - accuracy: 0.8399
# Epoch 151/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0240 - accuracy: 0.8401
# Epoch 152/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0240 - accuracy: 0.8399
# Epoch 153/200
# 20/20 [==============================] - 22s 1s/step - loss: 0.0240 - accuracy: 0.8399
# Epoch 154/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0239 - accuracy: 0.8401
# Epoch 155/200
# 20/20 [==============================] - 27s 1s/step - loss: 0.0240 - accuracy: 0.8399
# Epoch 156/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0239 - accuracy: 0.8401
# Epoch 157/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0238 - accuracy: 0.8401
# Epoch 158/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0237 - accuracy: 0.8401
# Epoch 159/200
# 20/20 [==============================] - 24s 1s/step - loss: 0.0238 - accuracy: 0.8402
# Epoch 160/200
# 20/20 [==============================] - 23s 1s/step - loss: 0.0237 - accuracy: 0.8402
# Epoch 161/200
# 20/20 [==============================] - 25s 1s/step - loss: 0.0237 - accuracy: 0.8403
# Done
#  Please wait while AnomalyDetector.h5 has been created
# Refresh when needed

# %%
from tensorflow.keras.utils import img_to_array,load_img
import numpy as np
import glob
import os 
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
import argparse
from PIL import Image

# %%
imagestore=[]


for i in range(1,46):
  video_source_path='content/UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test/'+str(i)
  imagestore=[]
  fps=5
#fps refers to the number of seconds after which one frame will be taken . fps=5 means 1 frame after every 5 seconds. More like seconds per frame.

  def create_dir(path):
	  if not os.path.exists(path):
		  os.makedirs(path)

  def remove_old_images(path):
	  filelist = glob.glob(os.path.join(path, "*.png"))
	  for f in filelist:
		  os.remove(f)

  def store(image_path):
	  img=load_img(image_path)
	  img=img_to_array(img)


	#Resize the Image to (227,227,3) for the network to be able to process it. 


	  img=resize(img,(227,227,3))

	#Convert the Image to Grayscale


	  gray=0.2989*img[:,:,0]+0.5870*img[:,:,1]+0.1140*img[:,:,2]

	  imagestore.append(gray)
#List of all Videos in the Source Directory.
  videos=os.listdir(video_source_path)
  print("Found ",len(videos)," testing videos")


#Make a temp dir to store all the frames
  create_dir(video_source_path+'/frames')

#Remove old images
  remove_old_images(video_source_path+'/frames')

  framepath=video_source_path+'/frames'
  total=0
  video_count=0

  for video in videos:
		  video_count+=1
		  print("Video number: ",video_count)
		  print("Video:",str(video))
		  image_count=0
		  os.system( 'ffmpeg -i {}/{} -r 1/{}  {}/frames/%03d.jpg'.format(video_source_path,video,fps,video_source_path))
		  images=os.listdir(framepath)
		  image_count=len(images)
		  for image in images:
			  image_path=framepath+ '/'+ image
			  store(image_path)
		  total=len(images)+total
		  print("Number of images:",image_count,"\n----------\n")


  imagestore=np.array(imagestore)
  a,b,c=imagestore.shape
#Reshape to (227,227,batch_size)
  imagestore.resize(b,c,a)
#Normalize
  imagestore=(imagestore-imagestore.mean())/(imagestore.std())
#Clip negative Values
  imagestore=np.clip(imagestore,0,1)
  np.save('tester.npy',imagestore)
#Remove Buffer Directory
  os.system('rm -r {}'.format(framepath))

  print("Program ended. All testing videos shall be stored in tester.npy \n Please wait while tester.npy is created. \nRefresh when needed")
  print('Number of frames created :', int(total))
  print ('Number of bunches=',int(total),"/10 = ",int(total/10))
  print("\nCorrupted and unreadable bunches were ignored")
# Out:
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored
# Found  1  testing videos
# Video number:  1
# Video: frames
# Number of images: 200
# ----------
#
# Program ended. All testing videos shall be stored in tester.npy
#  Please wait while tester.npy is created.
# Refresh when needed
# Number of frames created : 200
# Number of bunches= 200 /10 =  20
#
# Corrupted and unreadable bunches were ignored

# %%
from keras.models import load_model
import numpy as np

# %%
def mean_squared_loss(x1,x2):
	diff=x1-x2
	a,b,c,d,e=diff.shape
	n_samples=a*b*c*d*e
	sq_diff=diff**2
	Sum=sq_diff.sum()
	dist=np.sqrt(Sum)
	mean_dist=dist/n_samples

	return mean_dist



threshold=0.00025 #(Accuracy level 1)
#threshold=0.00042 #(Accuracy level 2)
#threshold=0.0008#(Accuracy level 3)

model=load_model('AnomalyDetector.h5')
import cv2


# define a video capture object
vid = cv2.VideoCapture(0)

while(True):
    ret, frame = vid.read()
    cv2.imshow('frame', frame)
X_test=np.load('frame')
frames=X_test.shape[2]
#Need to make number of frames divisible by 10


flag=0 #Overall video flagq

frames=frames-frames%10

X_test=X_test[:,:,:frames]
X_test=X_test.reshape(-1,227,227,10)
X_test=np.expand_dims(X_test,axis=4)
counter =0
for number,bunch in enumerate(X_test):
	n_bunch=np.expand_dims(bunch,axis=0)
	reconstructed_bunch=model.predict(n_bunch)


	loss=mean_squared_loss(n_bunch,reconstructed_bunch)
	
	if loss>threshold:
		print("Anomalous bunch of frames at bunch number {}".format(number))
		counter=counter+1
		print("bunch number: ",counter)
		flag=1


	else:
		print('No anomaly')
		counter=counter+1
		print("bunch number: ",counter)



if flag==1:
	print("Anomalous Events detected")
else:
	print("No anomaly detected")
	
print("\nCorrupted and unreadable bunches were ignored")
